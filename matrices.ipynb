# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Experimentacion_Victor.csv", encoding='latin-1')

# %%
df1 =  pd.read_csv("Experimentacion_Rosario.csv", encoding='latin-1')

# %%
df2 = pd.read_csv("Experimentacion_Itzel.csv", encoding='latin-1')

# %%
df3 = pd.read_csv("Experimentacion_Daniel.csv", encoding='latin-1')

# %%
df4 =  pd.read_csv("Experimentacion_Fernanda.csv", encoding='latin-1')

# %%
df_data =  pd.concat([df,df1, df2, df3, df4], axis=0, ignore_index=False)

# %%
df_data.to_csv("Experimentaciones.csv", encoding='latin-1', index=False)

# %%
df_data =  pd.read_csv("Experimentaciones.csv", encoding='latin-1')

# %%
df_data.drop(columns='Unnamed: 0', inplace=True)

# %%
df_data
# Out:
#     SEÑA ESPERADA HUAWEI/5001  DISTANCIA TOTAL  #INCIDENCIAS     FALSAS
# 0               A           A       101035.253            10      E/S/T  \
# 1               B           B        49944.526             7  HLA/M/MAL
# 2              BN          BN       124366.082            10    B/HLA/Ñ
# 3               C         MAL        45136.491             6    M/C/O/Ñ
# 4             CME         CME       403691.071            13          -
# ..            ...         ...              ...           ...        ...
# 180             X          YO        56143.762             5   G/O/TU/X
# 181             Y           Y       104518.627             8        PDN
# 182            YO          YO       166322.628            12         TU
# 183             Z           Z        97588.035             7    D/I/K/R
# 184             Ñ           U        48425.592             5   N/NO/R/Ñ
#
#     SAMSUNG-B/5000  DISTANCIA TOTAL.1  #INCIDENCIAS.1          FALSAS.1
# ...

# %%
df_data[["FALSAS", "FALSAS.1", "FALSAS.2"]] = df_data[["FALSAS", "FALSAS.1", "FALSAS.2"]].replace("-", "0")

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SEÑA ESPERADA      185 non-null    object
#  1   HUAWEI/5001        185 non-null    object
#  2   DISTANCIA TOTAL    185 non-null    float64
#  3   #INCIDENCIAS       185 non-null    int64
#  4   FALSAS             185 non-null    object
#  5   SAMSUNG-B/5000     185 non-null    object
#  6   DISTANCIA TOTAL.1  185 non-null    float64
#  7   #INCIDENCIAS.1     185 non-null    int64
#  8   FALSAS.1           185 non-null    object
#  9   S8/5003            185 non-null    object
#  10  DISTANCIA TOTAL.2  185 non-null    float64
#  11  #INCIDENCIAS.2     185 non-null    int64
#  12  FALSAS.2           185 non-null    object
# dtypes: float64(3), int64(3), object(7)
# memory usage: 18.9+ KB

# %%
df_data.to_csv("Experimentaciones.csv", encoding='latin-1', index=False)

# %%
df_data['HUAWEI/5001'] = df_data.apply(lambda row: 1 if row['SEÑA ESPERADA'] == row['HUAWEI/5001'] else 0, axis=1)

# %%
df_data['SAMSUNG-B/5000'] = df_data.apply(lambda row: 1 if row['SEÑA ESPERADA'] == row['SAMSUNG-B/5000'] else 0, axis=1)

# %%
df_data['S8/5003'] = df_data.apply(lambda row: 1 if row['SEÑA ESPERADA'] == row['S8/5003'] else 0, axis=1)

# %%
df_data
# Out:
#     SEÑA ESPERADA  HUAWEI/5001  DISTANCIA TOTAL  #INCIDENCIAS     FALSAS
# 0               A            1       101035.253            10      E/S/T  \
# 1               B            1        49944.526             7  HLA/M/MAL
# 2              BN            1       124366.082            10    B/HLA/Ñ
# 3               C            0        45136.491             6    M/C/O/Ñ
# 4             CME            1       403691.071            13          0
# ..            ...          ...              ...           ...        ...
# 180             X            0        56143.762             5   G/O/TU/X
# 181             Y            1       104518.627             8        PDN
# 182            YO            1       166322.628            12         TU
# 183             Z            1        97588.035             7    D/I/K/R
# 184             Ñ            0        48425.592             5   N/NO/R/Ñ
#
#      SAMSUNG-B/5000  DISTANCIA TOTAL.1  #INCIDENCIAS.1          FALSAS.1
# ...

# %%
df_data[['FALSAS','FALSAS.1','FALSAS.2']] = df_data[['FALSAS','FALSAS.1','FALSAS.2']].astype(str).apply(lambda x: x.str.count('/'))

# %%
df_data
# Out:
#     SEÑA ESPERADA  HUAWEI/5001  DISTANCIA TOTAL  #INCIDENCIAS  FALSAS
# 0               A            1       101035.253            10       2  \
# 1               B            1        49944.526             7       2
# 2              BN            1       124366.082            10       2
# 3               C            0        45136.491             6       3
# 4             CME            1       403691.071            13       0
# ..            ...          ...              ...           ...     ...
# 180             X            0        56143.762             5       3
# 181             Y            1       104518.627             8       0
# 182            YO            1       166322.628            12       0
# 183             Z            1        97588.035             7       3
# 184             Ñ            0        48425.592             5       3
#
#      SAMSUNG-B/5000  DISTANCIA TOTAL.1  #INCIDENCIAS.1  FALSAS.1  S8/5003
# ...

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SEÑA ESPERADA      185 non-null    object
#  1   HUAWEI/5001        185 non-null    int64
#  2   DISTANCIA TOTAL    185 non-null    float64
#  3   #INCIDENCIAS       185 non-null    int64
#  4   FALSAS             185 non-null    int64
#  5   SAMSUNG-B/5000     185 non-null    int64
#  6   DISTANCIA TOTAL.1  185 non-null    float64
#  7   #INCIDENCIAS.1     185 non-null    int64
#  8   FALSAS.1           185 non-null    int64
#  9   S8/5003            185 non-null    int64
#  10  DISTANCIA TOTAL.2  185 non-null    float64
#  11  #INCIDENCIAS.2     185 non-null    int64
#  12  FALSAS.2           185 non-null    int64
# dtypes: float64(3), int64(9), object(1)
# memory usage: 18.9+ KB

# %%
df_data.to_csv("data_generated.csv", encoding='latin-1', index=False)

# %%
# Out:
#    SEÑA ESPERADA HUAWEI/5001  DISTANCIA TOTAL  #INCIDENCIAS
# 0              A           A       101035.253            10  \
# 1              B           B        49944.526             7
# 2             BN          BN       124366.082            10
# 3              C         MAL        45136.491             6
# 4            CME         CME       403691.071            13
# 5              D           D       170117.488            13
# 6              E           E       147817.170            12
# 7              F           F       107782.675            13
# 8              G           G       104234.291            12
# 9            GRA         GRA       264370.813            13
# 10             H           H       120274.558            12
# 11           HLA         HLA        49976.531             7
# 12             I           I        96564.188             9
# 13             J           J        64776.866             6
# 14             K           K        94500.145             7
# ...

# %%
df1
# Out:
#     SEÑA ESPERADA HUAWEI/5001  DISTANCIA TOTAL  #INCIDENCIAS         FALSAS
# 0               A           A       105015.027            11            S/T  \
# 1               B           B        76562.419            13              -
# 2              BN          BN       140106.913             9        M/MAL/Ñ
# 3               C           C       113241.826            13              -
# 4             CME         CME       301272.746            11            A/Z
# 5               D           D       117083.183            12              Z
# 6               E           E        31302.847             2  A/D/E/I/N/O/T
# 7               F           F        52489.775             5              -
# 8               G           G       120144.854            11             YO
# 9             GRA        GRA        285956.811            13              -
# 10              H           H        77789.345             6      K/N/P/X/Ñ
# ...

# %%
df2
# Out:
#    SEÑA ESPERADA HUAWEI/5001  DISTANCIA TOTAL  #INCIDENCIAS
# 0              A           A     121468.20750            10  \
# 1              B           B      53115.07721             7
# 2             BN          BN     139313.81000            10
# 3              C         MAL      62879.07308             6
# 4            CME         CME     425154.86450            13
# 5              D           D     175317.44140            13
# 6              E           E     167369.35860            13
# 7              F           F     112547.44230            13
# 8              G           G     109265.90290            12
# 9            GRA         GRA     273527.63380            13
# 10             H           H     137142.34090            12
# 11           HLA         HLA      63153.83825             7
# 12             I           I     102900.87000            10
# 13             J           J      68679.61219             6
# 14             K           K     104961.51560             7
# ...

# %%
df3
# Out:
#    SEÑA ESPERADA HUAWEI/5001  DISTANCIA TOTAL  #INCIDENCIAS
# 0              A           A     105372.92940            11  \
# 1              B           B      52012.37321             8
# 2             BN          BN     133477.88850            12
# 3              C         MAL      62793.65893             6
# 4            CME         CME     412432.47450            13
# 5              D           D     189636.55190            13
# 6              E           E     162868.35440            12
# 7              F           F     121607.97010            13
# 8              G           G     108635.01250            12
# 9            GRA         GRA     271263.19580            13
# 10             H           H     122555.04670            13
# 11           HLA         HLA      50999.21613             7
# 12             I           I     117403.64000            10
# 13             J           J      69299.88149             7
# 14             K           K     107811.99200             8
# ...

# %%
df4
# Out:
#     SEÑA ESPERADA HUAWEI/5001  DISTANCIA TOTAL  #INCIDENCIAS
# 0               A           A        73260.323             8  \
# 1               B           B        86668.201            13
# 2              BN          BN        42848.897             4
# 3               C           C        95691.419            12
# 4             CME         CME       373233.038            12
# 5               D           D       134923.637            13
# 6               E           E        74507.909             6
# 7               F           F        11651.344            13
# 8               G           G        90270.411             9
# 9             GRA         GRA       202862.100            13
# 10              H           H        70125.365             7
# 11            HLA         HLA        81055.063            10
# 12              I           I        91270.968             9
# 13              J           J        74135.039             8
# ...

# %%
import pandas as pd
import numpy as np

# %%
df_test =  pd.read_csv("Pruebas.csv", encoding='latin-1')

# %%
df_test
# Out:
#      SEÑA ESPERADA  HUAWEI/5001  DISTANCIA TOTAL  #INCIDENCIAS  FALSAS
# 0                A            0       105015.027            11       2  \
# 1                B            0        76562.419            13       1
# 2               BN            0       140106.913             9       3
# 3                C            0       113241.826            13       1
# 4              CME            0       301272.746            11       2
# ..             ...          ...              ...           ...     ...
# 143              X            0        56143.762             5       4
# 144              Y            0       104518.627             8       1
# 145             YO            0       166322.628            12       1
# 146              Z            0        97588.035             7       4
# 147              Ñ            0        48425.592             5       4
#
#      SAMSUNG-B/5000  DISTANCIA TOTAL.1  #INCIDENCIAS.1  FALSAS.1  S8/5003
# ...
